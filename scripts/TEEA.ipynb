# %% [markdown]
# <a href="https://colab.research.google.com/github/rushil1904/Transposable-Elements-Expression-Analysis/blob/main/TEEA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
raw_counts = pd.read_csv("RE_raw.csv")
raw_counts
# Out:
#        Unnamed: 0  ...  TCGA-BT-A20O-01A-21R-A14Y-07
# 0            (A)n  ...                     11.600558
# 1          (AAA)n  ...                      0.000000
# 2      (AAAAAAC)n  ...                      0.000000
# 3      (AAAAAAG)n  ...                      0.000000
# 4      (AAAAAAT)n  ...                      0.000000
# ...           ...  ...                           ...
# 15417     X8_LINE  ...                      1.000000
# 15418     X9_LINE  ...                     11.946030
# 15419      Zaphod  ...                    127.805312
# 15420     Zaphod2  ...                     17.741067
# 15421     Zaphod3  ...                     35.959550
#
# [15422 rows x 434 columns]

# %%
gene_counts = pd.read_csv("GENE_raw.csv")
gene_counts
# Out:
#                             Unnamed: 0  ...  fff0c51e-fbf0-4eb2-9b38-962bf4433c6b
# 0                      ENSG00000000003  ...                             878.16570
# 1                      ENSG00000000005  ...                               3.00000
# 2                      ENSG00000000419  ...                            1369.00270
# 3                      ENSG00000000457  ...                             823.42870
# 4                      ENSG00000000460  ...                             939.07509
# ...                                ...  ...                                   ...
# 57369                  ENSG00000284701  ...                               0.00000
# 57370                  ENSG00000284723  ...                               0.00000
# 57371  ENSG00000284733,ENSG00000284662  ...                               0.00000
# 57372                  ENSG00000284741  ...                               0.00000
# ...

# %%
df_id = pd.read_csv("id_table.csv")
df_id
# Out:
#                                        id  ...                             file_name
# 0    6da42860-f8f8-4359-97b5-d0f5d78cc04a  ...  4cd267cf-fb3c-4e3c-9dc4-ca866586ae44
# 1    d5e61fa8-0432-448e-89a9-864f4170f1f5  ...  fd324ce0-1249-461e-a378-c1c2e462c9ae
# 2    2dc18376-84f6-4b24-8b27-ecad1edb0daf  ...  38d189fa-47d7-4d36-a057-47be1bda5db8
# 3    3ba4ba60-19e6-465e-bc86-48171fb84007  ...  dbcefade-ab9e-42f3-a37c-75a01d05a636
# 4    c08fe87f-6490-4a45-bf47-722b4462dcd6  ...  a74bbbf5-bb97-4458-99ea-d119f9373706
# ..                                    ...  ...                                   ...
# 428  6ff45346-35de-4971-874c-1d96f5f70f01  ...  db76b36f-3d71-487e-b79f-264a46b17741
# 429  2a03abac-f1a2-49a9-a57c-7543739dd862  ...  a5d86cde-32ca-4ed6-b1a5-5a47575f2ac6
# 430  06cf1614-52d7-4c9b-9782-72f56c394d8f  ...  fccca29a-f137-4d50-8469-8e8497f90b7a
# 431  6f6faf25-a173-4ee3-9f58-e02f4992e078  ...  b392e959-fae8-493d-b55e-7149ce9bfe4f
# ...

# %%
df_id.set_index('file_name',inplace=True)
df_id
# Out:
#                                                                         id                       barcode
# file_name
# 4cd267cf-fb3c-4e3c-9dc4-ca866586ae44  6da42860-f8f8-4359-97b5-d0f5d78cc04a  TCGA-KQ-A41P-01A-12R-A33J-07
# fd324ce0-1249-461e-a378-c1c2e462c9ae  d5e61fa8-0432-448e-89a9-864f4170f1f5  TCGA-DK-AA71-01A-31R-A39I-07
# 38d189fa-47d7-4d36-a057-47be1bda5db8  2dc18376-84f6-4b24-8b27-ecad1edb0daf  TCGA-CF-A3MI-01A-11R-A20F-07
# dbcefade-ab9e-42f3-a37c-75a01d05a636  3ba4ba60-19e6-465e-bc86-48171fb84007  TCGA-C4-A0EZ-01A-21R-A24X-07
# a74bbbf5-bb97-4458-99ea-d119f9373706  c08fe87f-6490-4a45-bf47-722b4462dcd6  TCGA-CU-A3QU-01A-11R-A22U-07
# ...                                                                    ...                           ...
# db76b36f-3d71-487e-b79f-264a46b17741  6ff45346-35de-4971-874c-1d96f5f70f01  TCGA-FD-A6TF-01A-52R-A32O-07
# a5d86cde-32ca-4ed6-b1a5-5a47575f2ac6  2a03abac-f1a2-49a9-a57c-7543739dd862  TCGA-GU-A767-01A-11R-A32O-07
# ...

# %%
my_dict = df_id.to_dict()['barcode']
my_dict
# Out:
# {'0082bb8f-6aa4-441c-8c53-43c2b1a34a52': 'TCGA-GU-A42Q-01A-11R-A23W-07',
#  '02174afb-00e1-4165-84d5-28168b9f3f1e': 'TCGA-E7-A6MD-01A-41R-A352-07',
#  '0233f814-d256-4bb3-b2f6-53b575ad7312': 'TCGA-CF-A3MG-01A-11R-A20F-07',
#  '03b2efe6-f689-42ab-a6fa-21b2f058fffc': 'TCGA-ZF-AA4X-01A-11R-A38B-07',
#  '04688f35-d23b-474f-938d-5cac13080f93': 'TCGA-H4-A2HQ-01A-11R-A180-07',
#  '06cd399b-c3d5-44fc-b0be-f3fe0b866efd': 'TCGA-GD-A3OP-11A-11R-A220-07',
#  '083a1d65-1bca-414e-8193-92670662e47f': 'TCGA-2F-A9KO-01A-11R-A38B-07',
#  '094f1b0d-ce3b-4f9f-b878-4c472248b373': 'TCGA-UY-A9PH-01A-11R-A38B-07',
#  '09ed993b-cfe6-4963-bdb6-c6844ac762c1': 'TCGA-DK-AA6W-01A-12R-A39I-07',
#  '09f31b55-df37-4673-8a8c-bde9bc8780c4': 'TCGA-DK-A6B0-01A-11R-A31N-07',
#  '0a9d5292-0681-4e04-8c80-05018d825263': 'TCGA-E7-A3X6-01A-12R-A22U-07',
#  '0b9f3d68-0a84-4d25-af2d-b11375f0f963': 'TCGA-XF-AAN4-01A-11R-A42T-07',
#  '0bc48c4c-23b3-4da5-baa5-dc81d04615ba': 'TCGA-K4-A5RJ-01A-11R-A28M-07',
# ...

# %%
values = list(gene_counts.columns.values)[1:]
values
# Out:
# ['0082bb8f-6aa4-441c-8c53-43c2b1a34a52',
#  '02174afb-00e1-4165-84d5-28168b9f3f1e',
#  '0233f814-d256-4bb3-b2f6-53b575ad7312',
#  '03b2efe6-f689-42ab-a6fa-21b2f058fffc',
#  '04688f35-d23b-474f-938d-5cac13080f93',
#  '06cd399b-c3d5-44fc-b0be-f3fe0b866efd',
#  '083a1d65-1bca-414e-8193-92670662e47f',
#  '094f1b0d-ce3b-4f9f-b878-4c472248b373',
#  '09ed993b-cfe6-4963-bdb6-c6844ac762c1',
#  '09f31b55-df37-4673-8a8c-bde9bc8780c4',
#  '0a9d5292-0681-4e04-8c80-05018d825263',
#  '0b9f3d68-0a84-4d25-af2d-b11375f0f963',
#  '0bc48c4c-23b3-4da5-baa5-dc81d04615ba',
#  '0c54f94f-141b-4786-b409-e2e0518b1ffc',
#  '0c96e49c-ccb1-440b-bcc0-86735abc22b8',
#  '0caba747-5ec1-41b4-89a2-de6d9c858d6e',
#  '0cb34818-6a44-4385-89ea-edb60198d980',
#  '0d29e2e4-6ea1-4a34-b5d5-aaff0a88d878',
#  '0d2ad2ca-52d2-44a0-9daa-6f7d4f43c37f',
#  '0d58fde5-ed73-4130-b05f-9c2bdc6ecd2c',
#  '0da0d95f-54bb-446a-8aa7-2c7ccd3a7341',
#  '0fb4d034-8453-414b-b40b-1753948cb4bf',
#  '10305a44-2df2-4078-9146-7bc82576d62b',
# ...

# %%
answer = []
for value in values:
    answer.append(my_dict[value])
    print(answer)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
answer.insert(0, 'Unnamed: 0')
answer
# Out:
# ['Unnamed: 0',
#  'TCGA-GU-A42Q-01A-11R-A23W-07',
#  'TCGA-E7-A6MD-01A-41R-A352-07',
#  'TCGA-CF-A3MG-01A-11R-A20F-07',
#  'TCGA-ZF-AA4X-01A-11R-A38B-07',
#  'TCGA-H4-A2HQ-01A-11R-A180-07',
#  'TCGA-GD-A3OP-11A-11R-A220-07',
#  'TCGA-2F-A9KO-01A-11R-A38B-07',
#  'TCGA-UY-A9PH-01A-11R-A38B-07',
#  'TCGA-DK-AA6W-01A-12R-A39I-07',
#  'TCGA-DK-A6B0-01A-11R-A31N-07',
#  'TCGA-E7-A3X6-01A-12R-A22U-07',
#  'TCGA-XF-AAN4-01A-11R-A42T-07',
#  'TCGA-K4-A5RJ-01A-11R-A28M-07',
#  'TCGA-K4-AAQO-01A-11R-A38B-07',
#  'TCGA-XF-A9T3-01A-11R-A42T-07',
#  'TCGA-CF-A1HR-01A-11R-A13Y-07',
#  'TCGA-GC-A3RC-01A-11R-A22U-07',
#  'TCGA-XF-A9SI-01A-11R-A39I-07',
#  'TCGA-CF-A47Y-01A-11R-A23W-07',
#  'TCGA-HQ-A5ND-01A-11R-A26T-07',
#  'TCGA-DK-A1AD-01A-11R-A13Y-07',
#  'TCGA-CF-A5UA-01A-11R-A28M-07',
#  'TCGA-BL-A0C8-01A-11R-A10U-07',
#  'TCGA-CF-A9FL-01A-11R-A38B-07',
#  'TCGA-BL-A0C8-01A-11R-A277-07',
#  'TCGA-DK-AA6M-01A-11R-A39I-07',
#  'TCGA-BT-A3PH-01A-11R-A220-07',
#  'TCGA-ZF-AA4U-01A-11R-A38B-07',
# ...

# %%
gene_counts.columns = answer

# %%
gene_counts
# Out:
#                             Unnamed: 0  ...  TCGA-BT-A20O-01A-21R-A14Y-07
# 0                      ENSG00000000003  ...                     878.16570
# 1                      ENSG00000000005  ...                       3.00000
# 2                      ENSG00000000419  ...                    1369.00270
# 3                      ENSG00000000457  ...                     823.42870
# 4                      ENSG00000000460  ...                     939.07509
# ...                                ...  ...                           ...
# 57369                  ENSG00000284701  ...                       0.00000
# 57370                  ENSG00000284723  ...                       0.00000
# 57371  ENSG00000284733,ENSG00000284662  ...                       0.00000
# 57372                  ENSG00000284741  ...                       0.00000
# 57373                              NaN  ...                     618.80575
#
# [57374 rows x 434 columns]

# %%
gene_counts.to_csv("GENE_raw_final.csv", index=False)

# %%
gene_counts_final = pd.read_csv('GENE_raw_final.csv')
gene_counts_final
# Out:
#            Unnamed: 0  ...  TCGA-BT-A20O-01A-21R-A14Y-07
# 0     ENSG00000000003  ...                    878.165700
# 1     ENSG00000000005  ...                      3.000000
# 2     ENSG00000000419  ...                   1369.002700
# 3     ENSG00000000457  ...                    823.428700
# 4     ENSG00000000460  ...                    939.075090
# ...               ...  ...                           ...
# 6755  ENSG00000133433  ...                     74.999960
# 6756  ENSG00000133454  ...                      0.000000
# 6757  ENSG00000133460  ...                    180.785882
# 6758  ENSG00000133466  ...                   1509.572900
# 6759  ENSG00000133475  ...                           NaN
#
# [6760 rows x 434 columns]

# %%
column1 = list(gene_counts.columns.values)[1:]
column2 = list(raw_counts.columns.values)[1:]
column1 == column2
# Out:
# True

# %%
a = raw_counts.mean(axis = 0, skipna = True).mean()
a
# Out:
# 101.97369359508988

# %%
b = gene_counts.mean(axis = 0, skipna = True).mean()
b
# Out:
# 951.5665711416987

# %%
combined_count = pd.concat([raw_counts, gene_counts])
combined_count
# Out:
#                             Unnamed: 0  ...  TCGA-BT-A20O-01A-21R-A14Y-07
# 0                                 (A)n  ...                     11.600558
# 1                               (AAA)n  ...                      0.000000
# 2                           (AAAAAAC)n  ...                      0.000000
# 3                           (AAAAAAG)n  ...                      0.000000
# 4                           (AAAAAAT)n  ...                      0.000000
# ...                                ...  ...                           ...
# 57369                  ENSG00000284701  ...                      0.000000
# 57370                  ENSG00000284723  ...                      0.000000
# 57371  ENSG00000284733,ENSG00000284662  ...                      0.000000
# 57372                  ENSG00000284741  ...                      0.000000
# 57373                              NaN  ...                    618.805750
#
# [72796 rows x 434 columns]

# %%
f = combined_count.mean(axis = 0, skipna = True).mean()
f
# Out:
# 771.5783663292943

# %%
normal_tissues = ['TCGA-BT-A20U-11A-11R-A14Y-07', 'TCGA-GC-A3WC-11A-11R-A22U-07','TCGA-BT-A20N-11A-11R-A14Y-07','TCGA-K4-A5RI-11A-11R-A28M-07','TCGA-GD-A3OP-11A-11R-A220-07',
                  'TCGA-BT-A20R-11A-11R-A16R-07','TCGA-GD-A3OQ-11A-21R-A220-07','TCGA-BT-A2LA-11A-11R-A18C-07','TCGA-K4-A3WV-11A-21R-A22U-07','TCGA-GC-A3BM-11A-11R-A22U-07',
                  'TCGA-BT-A20Q-11A-11R-A14Y-07','TCGA-K4-A54R-11A-11R-A26T-07','TCGA-CU-A0YN-11A-11R-A10U-07','TCGA-BL-A13J-11A-13R-A10U-07','TCGA-GC-A6I3-11A-11R-A31N-07',
                  'TCGA-CU-A0YR-11A-13R-A10U-07','TCGA-BT-A20W-11A-11R-A14Y-07','TCGA-GD-A2C5-11A-11R-A180-07','TCGA-BT-A2LB-11A-11R-A18C-07']

# %%
normal_raw_counts = combined_count[normal_tissues]
g = normal_raw_counts.mean().mean()
g
# Out:
# 748.3981095222323

# %%
tumor_raw_counts = combined_count.drop(normal_tissues, axis=1)
h = tumor_raw_counts.mean().mean()
h
# Out:
# 772.642194540246

# %%
introns_counts = pd.read_csv("RE_introns_file.csv")
introns_counts
# Out:
#        Unnamed: 0  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# 0            (A)n  ...                     73.439679
# 1      (AAAAAAC)n  ...                      0.000000
# 2      (AAAAAAG)n  ...                      0.000000
# 3      (AAAAAAT)n  ...                      0.000000
# 4       (AAAAAC)n  ...                      0.000000
# ...           ...  ...                           ...
# 11410     X8_LINE  ...                      0.000000
# 11411     X9_LINE  ...                      1.979140
# 11412      Zaphod  ...                     40.708487
# 11413     Zaphod2  ...                      1.691109
# 11414     Zaphod3  ...                    119.770110
#
# [11415 rows x 434 columns]

# %%
normal_tissues_with_RNA = ['Unnamed: 0','TCGA-BT-A20U-11A-11R-A14Y-07', 'TCGA-GC-A3WC-11A-11R-A22U-07','TCGA-BT-A20N-11A-11R-A14Y-07','TCGA-K4-A5RI-11A-11R-A28M-07','TCGA-GD-A3OP-11A-11R-A220-07',
                  'TCGA-BT-A20R-11A-11R-A16R-07','TCGA-GD-A3OQ-11A-21R-A220-07','TCGA-BT-A2LA-11A-11R-A18C-07','TCGA-K4-A3WV-11A-21R-A22U-07','TCGA-GC-A3BM-11A-11R-A22U-07',
                  'TCGA-BT-A20Q-11A-11R-A14Y-07','TCGA-K4-A54R-11A-11R-A26T-07','TCGA-CU-A0YN-11A-11R-A10U-07','TCGA-BL-A13J-11A-13R-A10U-07','TCGA-GC-A6I3-11A-11R-A31N-07',
                  'TCGA-CU-A0YR-11A-13R-A10U-07','TCGA-BT-A20W-11A-11R-A14Y-07','TCGA-GD-A2C5-11A-11R-A180-07','TCGA-BT-A2LB-11A-11R-A18C-07']

# %%
c = introns_counts.mean(axis = 0, skipna = True).mean()
c
# Out:
# 45.782875722430994

# %%
normal_introns_count = introns_counts[normal_tissues]
normal_introns_count.mean().mean()
# Out:
# 32.60133021948617

# %%
tumor_introns_count = introns_counts.drop(normal_tissues, axis=1)
tumor_introns_count.mean().mean()
# Out:
# 46.38782587836326

# %%
introns_combined_counts = pd.concat([introns_counts, gene_counts])

# %%
print(introns_combined_counts.mean().mean())
print(introns_combined_counts[normal_tissues].mean().mean())
print(introns_combined_counts.drop(normal_tissues, axis=1).mean().mean())
# Out:
# 801.2588056092601
# 783.2347138872921
# 802.0859982245191

# %%
intergenic_counts = pd.read_csv("RE_intergenic_file.csv")

# %%
d = intergenic_counts.mean(axis = 0, skipna = True).mean()
d
# Out:
# 80.13600304147941

# %%
normal_intergenic_counts = intergenic_counts[normal_tissues]
normal_intergenic_counts.mean().mean()
# Out:
# 46.138543713042594

# %%
tumor_intergenic_counts = intergenic_counts.drop(normal_tissues, axis=1)
tumor_intergenic_counts.mean().mean()
# Out:
# 81.69627291404052

# %%
intergenic_combined_counts = pd.concat([intergenic_counts, gene_counts])

# %%
print(intergenic_combined_counts.mean().mean())
print(intergenic_combined_counts[normal_tissues].mean().mean())
print(intergenic_combined_counts.drop(normal_tissues, axis=1).mean().mean())
# Out:
# 814.9172830100575
# 793.5760215530491
# 815.8967128836885

# %%
exons_counts = pd.read_csv("RE_exons_file.csv")
exons_counts
# Out:
#       Unnamed: 0  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# 0           (A)n  ...                       0.00000
# 1      (AAAAAC)n  ...                       0.00000
# 2     (AAAAACA)n  ...                       0.00000
# 3      (AAAAAG)n  ...                       0.00000
# 4      (AAAAAT)n  ...                       0.00000
# ...          ...  ...                           ...
# 4574     X8_LINE  ...                       2.59926
# 4575     X9_LINE  ...                       3.54121
# 4576      Zaphod  ...                       0.00000
# 4577     Zaphod2  ...                       0.00000
# 4578     Zaphod3  ...                       2.84821
#
# [4579 rows x 434 columns]

# %%
e = exons_counts.mean(axis = 0, skipna = True).mean()
e
# Out:
# 42.58039392866153

# %%
normal_exon_count = exons_counts[normal_tissues]
normal_exon_count.mean().mean()
# Out:
# 24.057170947655262

# %%
tumor_exon_count = exons_counts.drop(normal_tissues, axis=1)
tumor_exon_count.mean().mean()
# Out:
# 43.430493534070024

# %%
exon_combined_counts = pd.concat([exons_counts, gene_counts])

# %%
print(exon_combined_counts.mean().mean())
print(exon_combined_counts[normal_tissues].mean().mean())
print(exon_combined_counts.drop(normal_tissues, axis=1).mean().mean())
# Out:
# 884.3826138602357
# 865.4293792860201
# 885.2524482972163

# %%
pair_tumor = [w.replace('11A', '01A') for w in normal_tissues]

# %%
pair_tumor
# Out:
# ['TCGA-BT-A20U-01A-11R-A14Y-07',
#  'TCGA-GC-A3WC-01A-11R-A22U-07',
#  'TCGA-BT-A20N-01A-11R-A14Y-07',
#  'TCGA-K4-A5RI-01A-11R-A28M-07',
#  'TCGA-GD-A3OP-01A-11R-A220-07',
#  'TCGA-BT-A20R-01A-11R-A16R-07',
#  'TCGA-GD-A3OQ-01A-21R-A220-07',
#  'TCGA-BT-A2LA-01A-11R-A18C-07',
#  'TCGA-K4-A3WV-01A-21R-A22U-07',
#  'TCGA-GC-A3BM-01A-11R-A22U-07',
#  'TCGA-BT-A20Q-01A-11R-A14Y-07',
#  'TCGA-K4-A54R-01A-11R-A26T-07',
#  'TCGA-CU-A0YN-01A-11R-A10U-07',
#  'TCGA-BL-A13J-01A-13R-A10U-07',
#  'TCGA-GC-A6I3-01A-11R-A31N-07',
#  'TCGA-CU-A0YR-01A-13R-A10U-07',
#  'TCGA-BT-A20W-01A-11R-A14Y-07',
#  'TCGA-GD-A2C5-01A-11R-A180-07',
#  'TCGA-BT-A2LB-01A-11R-A18C-07']

# %%
column2
# Out:
# ['TCGA-GU-A42Q-01A-11R-A23W-07',
#  'TCGA-E7-A6MD-01A-41R-A352-07',
#  'TCGA-CF-A3MG-01A-11R-A20F-07',
#  'TCGA-ZF-AA4X-01A-11R-A38B-07',
#  'TCGA-H4-A2HQ-01A-11R-A180-07',
#  'TCGA-GD-A3OP-11A-11R-A220-07',
#  'TCGA-2F-A9KO-01A-11R-A38B-07',
#  'TCGA-UY-A9PH-01A-11R-A38B-07',
#  'TCGA-DK-AA6W-01A-12R-A39I-07',
#  'TCGA-DK-A6B0-01A-11R-A31N-07',
#  'TCGA-E7-A3X6-01A-12R-A22U-07',
#  'TCGA-XF-AAN4-01A-11R-A42T-07',
#  'TCGA-K4-A5RJ-01A-11R-A28M-07',
#  'TCGA-K4-AAQO-01A-11R-A38B-07',
#  'TCGA-XF-A9T3-01A-11R-A42T-07',
#  'TCGA-CF-A1HR-01A-11R-A13Y-07',
#  'TCGA-GC-A3RC-01A-11R-A22U-07',
#  'TCGA-XF-A9SI-01A-11R-A39I-07',
#  'TCGA-CF-A47Y-01A-11R-A23W-07',
#  'TCGA-HQ-A5ND-01A-11R-A26T-07',
#  'TCGA-DK-A1AD-01A-11R-A13Y-07',
#  'TCGA-CF-A5UA-01A-11R-A28M-07',
#  'TCGA-BL-A0C8-01A-11R-A10U-07',
#  'TCGA-CF-A9FL-01A-11R-A38B-07',
#  'TCGA-BL-A0C8-01A-11R-A277-07',
#  'TCGA-DK-AA6M-01A-11R-A39I-07',
#  'TCGA-BT-A3PH-01A-11R-A220-07',
#  'TCGA-ZF-AA4U-01A-11R-A38B-07',
# ...

# %%
pairs = []
for i in pair_tumor:
    if i in column2:
        pairs.append(i)
    else:
        print(i + " not found")
pairs
# Out:
# TCGA-GC-A3WC-01A-11R-A22U-07 not found
# TCGA-GD-A3OP-01A-11R-A220-07 not found
# TCGA-BT-A20R-01A-11R-A16R-07 not found
# TCGA-GD-A3OQ-01A-21R-A220-07 not found
# TCGA-K4-A3WV-01A-21R-A22U-07 not found
# TCGA-CU-A0YN-01A-11R-A10U-07 not found
# TCGA-BL-A13J-01A-13R-A10U-07 not found
# TCGA-CU-A0YR-01A-13R-A10U-07 not found
# TCGA-BT-A20W-01A-11R-A14Y-07 not found
# TCGA-GD-A2C5-01A-11R-A180-07 not found
# ['TCGA-BT-A20U-01A-11R-A14Y-07',
#  'TCGA-BT-A20N-01A-11R-A14Y-07',
#  'TCGA-K4-A5RI-01A-11R-A28M-07',
#  'TCGA-BT-A2LA-01A-11R-A18C-07',
#  'TCGA-GC-A3BM-01A-11R-A22U-07',
#  'TCGA-BT-A20Q-01A-11R-A14Y-07',
#  'TCGA-K4-A54R-01A-11R-A26T-07',
#  'TCGA-GC-A6I3-01A-11R-A31N-07',
#  'TCGA-BT-A2LB-01A-11R-A18C-07']

# %%
pairs_2 = ['TCGA-GC-A3WC-01A-31R-A22U-07','TCGA-GD-A3OP-01A-21R-A220-07', 'TCGA-BT-A20R-01A-12R-A16R-07', 'TCGA-GD-A3OQ-01A-32R-A220-07', 'TCGA-K4-A3WV-01A-11R-A22U-07', 'TCGA-CU-A0YN-01A-21R-A10U-07', 'TCGA-BL-A13J-01A-11R-A10U-07', 'TCGA-CU-A0YR-01A-12R-A10U-07', 'TCGA-BT-A20W-01A-21R-A14Y-07', 'TCGA-GD-A2C5-01A-12R-A180-07']
len(pairs_2)
# Out:
# 10

# %%
len(pairs)
# Out:
# 9

# %%
paired_tumor_samples = pairs + pairs_2
paired_tumor_samples
len(paired_tumor_samples)
# Out:
# 19

# %%
paired_raw_counts = raw_counts[paired_tumor_samples]
paired_raw_counts
# Out:
#        TCGA-BT-A20U-01A-11R-A14Y-07  ...  TCGA-GD-A2C5-01A-12R-A180-07
# 0                          9.910187  ...                     25.730895
# 1                          0.000000  ...                      0.000000
# 2                          0.000000  ...                      0.000000
# 3                          0.000000  ...                      0.000000
# 4                          0.000000  ...                      0.000000
# ...                             ...  ...                           ...
# 15417                      2.861103  ...                      2.000000
# 15418                      6.347830  ...                     23.160454
# 15419                     96.713784  ...                    262.644256
# 15420                      5.957194  ...                     25.274137
# 15421                     32.660277  ...                    144.907895
#
# [15422 rows x 19 columns]

# %%
paired_raw_counts_final = pd.concat([paired_raw_counts, normal_raw_counts], axis=1)
paired_raw_counts_final
# Out:
#        TCGA-BT-A20U-01A-11R-A14Y-07  ...  TCGA-BT-A2LB-11A-11R-A18C-07
# 0                          9.910187  ...                     19.303927
# 1                          0.000000  ...                      0.000000
# 2                          0.000000  ...                      0.000000
# 3                          0.000000  ...                      0.000000
# 4                          0.000000  ...                      0.000000
# ...                             ...  ...                           ...
# 15417                      2.861103  ...                      2.000000
# 15418                      6.347830  ...                     26.775670
# 15419                     96.713784  ...                     83.256659
# 15420                      5.957194  ...                     19.023842
# 15421                     32.660277  ...                     86.065568
#
# [15422 rows x 38 columns]

# %%
paired_raw_counts_final.to_csv("Paired_counts_raw_final.csv", index=False)

# %%
significant_TE_raw = pd.read_csv("significant.csv")
significant_TE_raw
# Out:
#      Unnamed: 0    baseMean  ...        pvalue          padj
# 0      (AACAA)n   12.461819  ...  1.703675e-08  6.361259e-07
# 1    (AAGATAT)n    3.824208  ...  6.189480e-04  4.768847e-03
# 2     (AATATA)n    1.783035  ...  1.358441e-17  2.747446e-15
# 3      (AATGG)n   33.487526  ...  9.150546e-03  4.162862e-02
# 4    (AATTTGC)n    2.858327  ...  1.852913e-03  1.150830e-02
# ..          ...         ...  ...           ...           ...
# 562       UCON8   10.411687  ...  1.010857e-10  5.983782e-09
# 563  UCON80_AMi   37.783427  ...  1.244729e-04  1.243193e-03
# 564      UCON88    1.081048  ...  6.917032e-03  3.304653e-02
# 565    X5B_LINE    1.792099  ...  5.905780e-03  2.943718e-02
# 566      Zaphod  187.997792  ...  1.316516e-03  8.706222e-03
#
# [567 rows x 6 columns]

# %%
significant_TE_introns = pd.read_csv("significant_introns.csv")
significant_TE_introns
# Out:
#     Unnamed: 0    baseMean  log2FoldChange     lfcSE    pvalue      padj
# 0        (AC)n  104.608291       -0.515701  0.183712  0.001231  0.010356
# 1    (ACACAT)n   10.829772        0.593192  0.342293  0.007697  0.042755
# 2    (ACAGAG)n    1.962227       -1.988713  0.466342  0.000002  0.000043
# 3        (AT)n   11.954008       -0.475008  0.207061  0.005264  0.032422
# 4    (ATCACC)n    6.034129       -1.239282  0.337534  0.000019  0.000333
# ..         ...         ...             ...       ...       ...       ...
# 269   Tigger9b   35.537208       -0.305521  0.095954  0.000760  0.007074
# 270     UCON20    1.147858       -0.697132  0.462475  0.008636  0.046736
# 271     UCON34    0.440691       -2.094500  0.523810  0.000010  0.000200
# 272     UCON74   10.237024       -0.494887  0.187574  0.001826  0.014142
# 273   X7A_LINE    8.658324       -0.668664  0.158350  0.000003  0.000058
#
# [274 rows x 6 columns]

# %%
significant_TE_exon = pd.read_csv("significant_exons.csv")
significant_TE_exon
# Out:
#      Unnamed: 0   baseMean  ...        pvalue          padj
# 0         (AC)n  19.596167  ...  3.189567e-05  3.545071e-04
# 1      (ACCAC)n  18.504761  ...  7.360845e-08  1.915615e-06
# 2    (ACGCCAG)n   0.432071  ...  5.007920e-04  3.586209e-03
# 3       (CACA)n   9.631672  ...  9.772778e-09  3.066928e-07
# 4     (CACCCA)n   2.162435  ...  1.217327e-02  4.920029e-02
# ..          ...        ...  ...           ...           ...
# 263      UCON14   3.224280  ...  2.208728e-04  1.771964e-03
# 264      UCON29   9.667805  ...  1.860847e-03  1.039541e-02
# 265      UCON39  22.781211  ...  5.437538e-03  2.555883e-02
# 266  UCON80_AMi   0.984840  ...  4.784923e-04  3.473138e-03
# 267     Zaphod3   1.799785  ...  3.471192e-03  1.755338e-02
#
# [268 rows x 6 columns]

# %%
significant_TE_intergenic = pd.read_csv("significant_intergenic.csv")
significant_TE_intergenic
# Out:
#      Unnamed: 0    baseMean  ...        pvalue          padj
# 0          (A)n   17.978936  ...  1.926261e-03  1.320792e-02
# 1       (AAAC)n    1.504695  ...  8.558815e-03  4.442678e-02
# 2      (AACAA)n   12.094669  ...  2.989325e-08  1.179148e-06
# 3    (AAGATAT)n    3.711457  ...  7.069462e-04  5.933298e-03
# 4     (AATATA)n    1.787083  ...  1.992403e-16  3.678829e-14
# ..          ...         ...  ...           ...           ...
# 507       UCON8    5.834010  ...  2.252673e-10  1.386467e-08
# 508  UCON80_AMi   36.402675  ...  3.210688e-04  3.155752e-03
# 509      UCON88    0.860982  ...  7.315114e-03  3.906936e-02
# 510    X5B_LINE    1.754668  ...  6.002108e-03  3.368383e-02
# 511      Zaphod  155.236007  ...  1.332517e-04  1.524140e-03
#
# [512 rows x 6 columns]

# %%
significant_TE_raw = significant_TE_raw[['Unnamed: 0']]
significant_TE_raw
# Out:
#      Unnamed: 0
# 0      (AACAA)n
# 1    (AAGATAT)n
# 2     (AATATA)n
# 3      (AATGG)n
# 4    (AATTTGC)n
# ..          ...
# 562       UCON8
# 563  UCON80_AMi
# 564      UCON88
# 565    X5B_LINE
# 566      Zaphod
#
# [567 rows x 1 columns]

# %%
mapping_file = pd.read_csv('subfamily_to_class.csv')
mapping_file
# Out:
#     TE Subfamily TE Class
# 0          MER75      DNA
# 1          L1PA2     LINE
# 2           L1HS     LINE
# 3          LTR7Y      LTR
# 4        LTR2752      LTR
# ..           ...      ...
# 458       MER94B      DNA
# 459       LTR27D      LTR
# 460        L1P4d     LINE
# 461        LTR57      LTR
# 462        L1P4e     LINE
#
# [463 rows x 2 columns]

# %%
TE_subfamily = mapping_file['TE Subfamily'].tolist()
TE_subfamily
# Out:
# ['MER75',
#  'L1PA2',
#  'L1HS',
#  'LTR7Y',
#  'LTR2752',
#  'MST-int',
#  'HERVL18-int',
#  'MER61B',
#  'LTR75_1',
#  'L1PBa1',
#  'HERVH-int',
#  'HERVK11D-int',
#  'MER57F',
#  'L1PA3',
#  'HERV9-int',
#  'MLT1G1-int',
#  'LTR1B1',
#  'LTR18A',
#  'LTR1E',
#  'LTR48B',
#  'LTR76',
#  'HERV1_I-int',
#  'LTR2B',
#  'MER57-int',
#  'LTR12D',
#  'MER57A1',
#  'Harlequin-int',
#  'MER4A',
#  'LTR1A2',
#  'LTR16D2',
#  'HERV3-int',
#  'LTR51',
#  'SVA_B',
#  'LTR26C',
#  'L1PBb',
#  'HERV9NC-int',
#  'MER52C',
#  'SVA_A',
#  'HERVI-int',
#  'L1P1',
#  'PABL_B-int',
#  'HERV1_LTRd',
#  'MLT1J2-int',
#  'MER57E1',
#  'SVA_F',
#  'LTR43-int',
#  'L1P4b',
#  'LTR80B',
#  'MER110',
#  'HERVP71A-int',
#  'MER47C',
#  'HERVIP10F-int',
#  'LTR1C',
#  'HERVL66-int',
#  'MER66B',
#  'MER61E',
#  'L1PA5',
#  'MER76',
#  'MER52-int',
#  'THE1-int',
#  'LTR75',
#  'L1PB1',
#  'LTR1D1',
#  'MER70B',
#  'MamRep1527',
#  'L1PA8',
#  'LTR19B',
#  'MER68B',
#  'MER52A',
#  'SVA_D',
#  'L1PBa',
# ...

# %%
mapping_file.set_index('TE Subfamily',inplace=True)
mapping_file
# Out:
#              TE Class
# TE Subfamily
# MER75             DNA
# L1PA2            LINE
# L1HS             LINE
# LTR7Y             LTR
# LTR2752           LTR
# ...               ...
# MER94B            DNA
# LTR27D            LTR
# L1P4d            LINE
# LTR57             LTR
# L1P4e            LINE
#
# [463 rows x 1 columns]

# %%
map = mapping_file.to_dict()['TE Class']
map
# Out:
# {'Alu': 'SINE',
#  'AluSq4': 'SINE',
#  'AluYa5': 'SINE',
#  'AluYc3': 'SINE',
#  'AluYf1': 'SINE',
#  'AluYg6': 'SINE',
#  'AluYh3a3': 'SINE',
#  'AluYk2': 'SINE',
#  'AluYk3': 'SINE',
#  'AluYk4': 'SINE',
#  'AmnSINE1': 'SINE',
#  'AmnSINE2': 'SINE',
#  'CR1-3_Croc': 'LINE',
#  'Charlie10': 'DNA',
#  'Charlie11': 'DNA',
#  'Charlie13a': 'DNA',
#  'Charlie17': 'DNA',
#  'Charlie17a': 'DNA',
#  'Charlie1b': 'DNA',
#  'Charlie3': 'DNA',
#  'Charlie4': 'DNA',
#  'Charlie4z': 'DNA',
#  'Charlie6': 'DNA',
#  'Charlie7a': 'DNA',
#  'Charlie9': 'DNA',
#  'ERV24_Prim-int': 'LTR',
#  'ERV3-16A3_I-int': 'LTR',
#  'ERVL-int': 'LTR',
#  'FordPrefect': 'DNA',
#  'FordPrefect_a': 'DNA',
#  'HAL1M8': 'LINE',
#  'HERV-Fc1-int': 'LTR',
#  'HERV-Fc2-int': 'LTR',
#  'HERV15-int': 'LTR',
#  'HERV16-int': 'LTR',
#  'HERV17-int': 'LTR',
#  'HERV1_I-int': 'LTR',
#  'HERV1_LTRc': 'LTR',
#  'HERV1_LTRd': 'LTR',
#  'HERV3-int': 'LTR',
#  'HERV30-int': 'LTR',
#  'HERV35I-int': 'LTR',
#  'HERV4_I-int': 'LTR',
# ...

# %%
significant_TE_raw = significant_TE_raw['Unnamed: 0'].tolist()

# %%
significant_TE_raw
# Out:
# ['(AACAA)n',
#  '(AAGATAT)n',
#  '(AATATA)n',
#  '(AATGG)n',
#  '(AATTTGC)n',
#  '(ACACAC)n',
#  '(ACACACC)n',
#  '(ACAGAG)n',
#  '(ACATAC)n',
#  '(ACCAC)n',
#  '(ACGCCAG)n',
#  '(AGA)n',
#  '(AGAA)n',
#  '(AGCAGC)n',
#  '(AGCGAG)n',
#  '(AGGA)n',
#  '(AGGCAA)n',
#  '(AT)n',
#  '(ATAC)n',
#  '(ATATTC)n',
#  '(ATATTT)n',
#  '(ATATTTT)n',
#  '(ATCACC)n',
#  '(ATCC)n',
#  '(ATG)n',
#  '(ATGG)n',
#  '(ATGGA)n',
#  '(ATGTGT)n',
#  '(ATTAA)n',
#  '(ATTAGTA)n',
#  '(ATTC)n',
#  '(ATTCC)n',
#  '(ATTCCATTCC)n',
#  '(ATTTAT)n',
#  '(C)n',
#  '(CA)n',
#  '(CACA)n',
#  '(CACAACA)n',
#  '(CACCCA)n',
#  '(CAGACC)n',
#  '(CAGGTG)n',
#  '(CATCAT)n',
#  '(CATT)n',
#  '(CATTC)n',
#  '(CCAAGCCAG)n',
#  '(CCATT)n',
#  '(CCC)n',
#  '(CCCCAG)n',
#  '(CCCCT)n',
#  '(CCCCTC)n',
#  '(CCCTCA)n',
#  '(CCCTCCC)n',
#  '(CCGCCC)n',
#  '(CCGCTT)n',
#  '(CCGGCC)n',
#  '(CCTAAC)n',
#  '(CCTC)n',
#  '(CCTCAG)n',
#  '(CCTGAT)n',
#  '(CCTGCA)n',
#  '(CCTGCCT)n',
#  '(CCTGTTG)n',
#  '(CGCCGCC)n',
#  '(CGCGCCC)n',
# ...

# %%
TE_class = []
for TE in significant_TE_raw:
    if TE in TE_subfamily:
        TE_class.append(map[TE])
print(TE_class)
# Out:
# ['SINE', 'DNA', 'DNA', 'DNA', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'DNA', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LINE', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'DNA', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'DNA', 'DNA', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LTR', 'LT
# ...

# %%
from collections import LCounter
Counter(TE_class)
# Out:
# Counter({'DNA': 13, 'LINE': 20, 'LTR': 151, 'Retroposon': 4, 'SINE': 1})

# %%
normal_tissues_introns = introns_counts[normal_tissues_with_RNA]

# %%
normal_tissues_introns = normal_tissues_introns.set_index(normal_tissues_introns.columns[0])

# %%
normal_tissues_introns = normal_tissues_introns[(normal_tissues_introns!=0).any(axis=1)]
normal_tissues_introns
# Out:
#             TCGA-BT-A20U-11A-11R-A14Y-07  ...  TCGA-BT-A2LB-11A-11R-A18C-07
# Unnamed: 0                                ...
# (A)n                            1.937150  ...                     13.314396
# (AAAAC)n                        0.000000  ...                      0.000000
# (AAAACAA)n                      0.000000  ...                      0.000000
# (AAAAT)n                        0.000000  ...                      0.000000
# (AAAATA)n                       0.000000  ...                      0.000000
# ...                                  ...  ...                           ...
# X8_LINE                         0.000000  ...                      0.000000
# X9_LINE                         1.770670  ...                      2.000000
# Zaphod                         14.172189  ...                     14.347959
# Zaphod2                         2.510807  ...                      3.202252
# Zaphod3                        14.426101  ...                     32.946863
#
# ...

# %%
RNA_introns_list = introns_counts['Unnamed: 0'].tolist()

# %%
TE_class_introns = []
TE_subfamily_introns = []
TE_not_found_introns = []
for TE in RNA_introns_list:
    if TE in TE_subfamily:
        #print(TE + ' found')
        TE_subfamily_introns.append(TE)
        TE_class_introns.append(map[TE])
    else:
        #print(TE + ' not found')
        TE_not_found_introns.append(TE)
print(TE_subfamily_introns)
# Out:
# ['Alu', 'AluSq4', 'AluYa5', 'AluYc3', 'AluYf1', 'AluYg6', 'AluYh3a3', 'AluYk2', 'AluYk3', 'AluYk4', 'AmnSINE1', 'AmnSINE2', 'Charlie10', 'Charlie11', 'Charlie13a', 'Charlie17', 'Charlie17a', 'Charlie1b', 'Charlie3', 'Charlie4', 'Charlie4z', 'Charlie6', 'Charlie7a', 'Charlie9', 'CR1-3_Croc', 'ERV24_Prim-int', 'ERV3-16A3_I-int', 'ERVL-int', 'FordPrefect', 'FordPrefect_a', 'HAL1M8', 'Harlequin-int', 'hAT-N1_Mam', 'HERV-Fc1-int', 'HERV1_I-int', 'HERV1_LTRc', 'HERV1_LTRd', 'HERV15-int', 'HERV16-int', 'HERV17-int', 'HERV3-int', 'HERV30-int', 'HERV35I-int', 'HERV4_I-int', 'HERV9-int', 'HERV9N-int', 'HERV9NC-int', 'HERVE_a-int', 'HERVE-int', 'HERVFH19-int', 'HERVFH21-int', 'HERVH-int', 'HERVH48-int', 'HERVI-int', 'HERVIP10B3-int', 'HERVIP10F-int', 'HERVIP10FH-int', 'HERVK-int', 'HERVK11-int', 'HERVK11D-int', 'HERVK13-int', 'HERVK14C-int', 'HERVK22-int', 'HERVK3-int', 'HERVK9-int', 'HERVL-int', 'HERVL18-int', 'HERVL66-int', 'HERVP71A-int', 'HERVS71-int', 'HUERS-P2-int', 'HUERS-P3-int', 'Kanga
# ...

# %%
normal_tissue_introns_final = normal_tissues_introns.loc[['Alu', 'AluSq4', 'AluYa5', 'AluYc3', 'AluYf1', 'AluYg6', 'AluYh3a3', 'AluYk2', 'AluYk3', 'AluYk4', 'AmnSINE1', 'AmnSINE2', 'Charlie10', 'Charlie11', 'Charlie13a', 'Charlie17', 'Charlie17a', 'Charlie1b', 'Charlie3', 'Charlie4', 'Charlie4z', 'Charlie6', 'Charlie7a', 'Charlie9', 'CR1-3_Croc', 'ERV24_Prim-int', 'ERV3-16A3_I-int', 'ERVL-int', 'FordPrefect', 'FordPrefect_a', 'HAL1M8', 'Harlequin-int', 'hAT-N1_Mam', 'HERV1_I-int', 'HERV1_LTRc', 'HERV1_LTRd', 'HERV15-int', 'HERV16-int', 'HERV17-int', 'HERV3-int', 'HERV30-int', 'HERV35I-int', 'HERV4_I-int', 'HERV9-int', 'HERV9N-int', 'HERV9NC-int', 'HERVE_a-int', 'HERVE-int', 'HERVFH19-int', 'HERVFH21-int', 'HERVH-int', 'HERVH48-int', 'HERVI-int', 'HERVIP10B3-int', 'HERVIP10F-int', 'HERVIP10FH-int', 'HERVK-int', 'HERVK11-int', 'HERVK11D-int', 'HERVK13-int', 'HERVK14C-int', 'HERVK22-int', 'HERVK3-int', 'HERVK9-int', 'HERVL-int', 'HERVL18-int', 'HERVL66-int', 'HERVP71A-int', 'HERVS71-int', 'HUERS-P2-int', 'HUERS-P3-int', 'Kanga1', 'Kanga11a', 'Kanga1a', 'Kanga1b', 'Kanga1c', 'Kanga1d', 'Kanga2_a', 'L1HS', 'L1M1', 'L1M2', 'L1M2a1', 'L1M2b', 'L1M2c', 'L1M3', 'L1M3a', 'L1M3b', 'L1M3c', 'L1M3d', 'L1M3e', 'L1M3f', 'L1M4a2', 'L1M4c', 'L1M6', 'L1M7', 'L1M8', 'L1MA1', 'L1MA10', 'L1MA3', 'L1MA4A', 'L1MB1', 'L1MC', 'L1MD3', 'L1ME3D', 'L1ME3F', 'L1MEa', 'L1MEg1', 'L1MEg2', 'L1P1', 'L1P2', 'L1P3', 'L1P4', 'L1P4a', 'L1P4b', 'L1P4d', 'L1P4e', 'L1PA11', 'L1PA12', 'L1PA13', 'L1PA14', 'L1PA15', 'L1PA15-16', 'L1PA2', 'L1PA3', 'L1PA5', 'L1PA6', 'L1PA7', 'L1PA8', 'L1PA8A', 'L1PB1', 'L1PB2', 'L1PB3', 'L1PBa', 'L1PBa1', 'L1PBb', 'L1PREC2', 'L2-1_AMi', 'L4_B_Mam', 'Looper', 'LOR1-int', 'LOR1a', 'LTR1', 'LTR102_Mam', 'LTR103b_Mam', 'LTR105_Mam', 'LTR106_Mam', 'LTR10A', 'LTR10C', 'LTR10E', 'LTR10F', 'LTR12B', 'LTR12C', 'LTR12D', 'LTR12F', 'LTR13_', 'LTR14', 'LTR14A', 'LTR14C', 'LTR16A2', 'LTR16B1', 'LTR16B2', 'LTR16D', 'LTR16D2', 'LTR16E2', 'LTR18A', 'LTR18B', 'LTR19A', 'LTR19B', 'LTR1A2', 'LTR1B', 'LTR1B0', 'LTR1B1', 'LTR1C', 'LTR1C1', 'LTR1D', 'LTR1D1', 'LTR1E', 'LTR1F', 'LTR1F1', 'LTR2', 'LTR21A', 'LTR21B', 'LTR22A', 'LTR22E', 'LTR23', 'LTR24C', 'LTR25-int', 'LTR26B', 'LTR26C', 'LTR26D', 'LTR26E', 'LTR27', 'LTR2752', 'LTR27B', 'LTR27C', 'LTR27D', 'LTR27E', 'LTR28', 'LTR28B', 'LTR28C', 'LTR29', 'LTR2B', 'LTR2C', 'LTR31', 'LTR33A_', 'LTR33C', 'LTR34', 'LTR35B', 'LTR37-int', 'LTR37A', 'LTR38', 'LTR38A1', 'LTR39', 'LTR39-int', 'LTR3A', 'LTR3B', 'LTR4', 'LTR40a', 'LTR40A1', 'LTR40c', 'LTR41', 'LTR43', 'LTR43-int', 'LTR43B', 'LTR44', 'LTR45', 'LTR45B', 'LTR45C', 'LTR46', 'LTR46-int', 'LTR47B2', 'LTR48', 'LTR48B', 'LTR49-int', 'LTR5_Hs', 'LTR51', 'LTR52', 'LTR53B', 'LTR55', 'LTR56', 'LTR57', 'LTR57-int', 'LTR61', 'LTR62', 'LTR64', 'LTR65', 'LTR66', 'LTR6A', 'LTR6B', 'LTR7', 'LTR70', 'LTR71A', 'LTR71B', 'LTR72', 'LTR73', 'LTR75', 'LTR75_1', 'LTR76', 'LTR7B', 'LTR7C', 'LTR7Y', 'LTR80A', 'LTR80B', 'LTR81B', 'LTR81C', 'LTR82A', 'LTR84a', 'LTR84b', 'LTR85a', 'LTR85b', 'LTR85c', 'LTR86B2', 'LTR86C', 'LTR88c', 'LTR9', 'LTR90B', 'LTR9A1', 'LTR9C', 'LTR9D', 'Mam_R4', 'MamGyp-int', 'MamGypLTR1a', 'MamGypsy2-I', 'MamGypsy2-LTR', 'MamRep1527', 'MamRep1894', 'MamRep4096', 'MamTip3', 'MER101', 'MER101B', 'MER102b', 'MER102c', 'MER105', 'MER110', 'MER110-int', 'MER113B', 'MER11A', 'MER11B', 'MER11C', 'MER11D', 'MER121', 'MER1B', 'MER20B', 'MER34', 'MER34-int', 'MER34A', 'MER34A1', 'MER34B', 'MER34B-int', 'MER34C2', 'MER34D', 'MER39', 'MER4-int', 'MER41A', 'MER41C', 'MER41G', 'MER44D', 'MER45B', 'MER45C', 'MER47C', 'MER48', 'MER49', 'MER4A', 'MER4A1', 'MER4A1_', 'MER4B-int', 'MER4C', 'MER4D', 'MER4D0', 'MER50', 'MER50-int', 'MER50B', 'MER50C', 'MER51-int', 'MER51A', 'MER51B', 'MER51C', 'MER51D', 'MER51E', 'MER52-int', 'MER52A', 'MER52C', 'MER52D', 'MER54B', 'MER57-int', 'MER57A-int', 'MER57A1', 'MER57B1', 'MER57B2', 'MER57C2', 'MER57D', 'MER57E1', 'MER57F', 'MER61-int', 'MER61A', 'MER61B', 'MER61C', 'MER61D', 'MER61E', 'MER61F', 'MER63B', 'MER65C', 'MER65D', 'MER66A', 'MER66B', 'MER66C', 'MER66D', 'MER67A', 'MER67D', 'MER68', 'MER68-int', 'MER68B', 'MER6A', 'MER70-int', 'MER70A', 'MER70B', 'MER72B', 'MER74C', 'MER75', 'MER76', 'MER77', 'MER83', 'MER83A-int', 'MER83B-int', 'MER84', 'MER87', 'MER87B', 'MER89-int', 'MER90', 'MER91C', 'MER94B', 'MER96', 'MER96B', 'MER97b', 'MER97c', 'MER9a1', 'MER9a2', 'MER9a3', 'MLT1-int', 'MLT1A-int', 'MLT1A0-int', 'MLT1C-int', 'MLT1E', 'MLT1E1', 'MLT1E1A', 'MLT1E2-int', 'MLT1E3', 'MLT1F2-int', 'MLT1G', 'MLT1G-int', 'MLT1G1-int', 'MLT1G3', 'MLT1H-int', 'MLT1H2', 'MLT1H2-int', 'MLT1I-int', 'MLT1J1-int', 'MLT1J2-int', 'MLT1K-int', 'MLT2B1', 'MLT2B5', 'MLT2C2', 'MST-int', 'MSTA-int', 'MSTB1', 'MSTB2-int', 'MSTD', 'MSTD-int', 'ORSL-2a', 'ORSL-2b', 'PABL_A', 'PABL_A-int', 'PABL_B', 'PABL_B-int', 'PRIMA41-int', 'PRIMAX-int', 'PrimLTR79', 'Ricksha', 'SVA_A', 'SVA_B', 'SVA_C', 'SVA_D', 'SVA_E', 'SVA_F', 'THE1-int', 'THE1D-int', 'Tigger12c', 'Tigger16b', 'Tigger17c', 'Tigger3c', 'Tigger4', 'Tigger5', 'Tigger6b', 'Tigger8', 'Tigger9a', 'X2_LINE', 'X7B_LINE', 'X7C_LINE', 'X8_LINE', 'Zaphod', 'Zaphod2']

]
normal_tissue_introns_final
# Out:
#             TCGA-BT-A20U-11A-11R-A14Y-07  ...  TCGA-BT-A2LB-11A-11R-A18C-07
# Unnamed: 0                                ...
# Alu                             7.628535  ...                      2.520924
# AluSq4                         35.378040  ...                     47.032849
# AluYa5                         22.022591  ...                     32.399845
# AluYc3                         13.841626  ...                     20.327469
# AluYf1                         40.491801  ...                     55.208917
# ...                                  ...  ...                           ...
# X7B_LINE                        4.327233  ...                      0.000000
# X7C_LINE                        0.890174  ...                      6.358590
# X8_LINE                         0.000000  ...                      0.000000
# Zaphod                         14.172189  ...                     14.347959
# Zaphod2                         2.510807  ...                      3.202252
#
# ...

# %%
list_introns = list(normal_tissue_introns_final.index.values)
list_class_introns = []
for x in list_introns:
    list_class_introns.append(map[x])

# %%
normal_tissue_introns_final
# Out:
#             TCGA-BT-A20U-11A-11R-A14Y-07  ...  TCGA-BT-A2LB-11A-11R-A18C-07
# Unnamed: 0                                ...
# Alu                             7.628535  ...                      2.520924
# AluSq4                         35.378040  ...                     47.032849
# AluYa5                         22.022591  ...                     32.399845
# AluYc3                         13.841626  ...                     20.327469
# AluYf1                         40.491801  ...                     55.208917
# ...                                  ...  ...                           ...
# X7B_LINE                        4.327233  ...                      0.000000
# X7C_LINE                        0.890174  ...                      6.358590
# X8_LINE                         0.000000  ...                      0.000000
# Zaphod                         14.172189  ...                     14.347959
# Zaphod2                         2.510807  ...                      3.202252
#
# ...

# %%
subfamily_introns_normal_mean = normal_tissue_introns_final.mean(axis=1)
subfamily_introns_normal_mean.head(50)
subfamily_introns_normal_mean.to_csv("subfamily_introns_normal_mean.csv")

# %%
normal_tissue_introns_final['Class'] = list_class_introns

# %%
normal_tissue_introns_final = normal_tissue_introns_final.set_index('Class')

# %%
normal_tissue_introns_final_transposed = normal_tissue_introns_final.T
normal_tissue_introns_final_transposed
normal_tissue_introns_final_transposed.groupby(by=normal_tissue_introns_final_transposed.columns, axis=1).mean().mean()
# Out:
# Class
# DNA            25.136541
# LINE          185.544880
# LTR            47.698026
# Retroposon    360.187742
# SINE           25.631004
# dtype: float64

# %%
normal_tissues_exons = exons_counts[normal_tissues_with_RNA]

# %%
normal_tissues_exons
# Out:
#       Unnamed: 0  ...  TCGA-BT-A2LB-11A-11R-A18C-07
# 0           (A)n  ...                      0.000000
# 1      (AAAAAC)n  ...                      0.000000
# 2     (AAAAACA)n  ...                      0.000000
# 3      (AAAAAG)n  ...                      0.000000
# 4      (AAAAAT)n  ...                      0.000000
# ...          ...  ...                           ...
# 4574     X8_LINE  ...                      0.000000
# 4575     X9_LINE  ...                      2.775670
# 4576      Zaphod  ...                      0.000000
# 4577     Zaphod2  ...                      8.821590
# 4578     Zaphod3  ...                      2.118705
#
# [4579 rows x 20 columns]

# %%
RNA_exons_list = exons_counts['Unnamed: 0'].tolist()
len(RNA_exons_list)
# Out:
# 4579

# %%
TE_class_exons = []
TE_subfamily_exons = []
TE_not_found_exons = []
for TE in RNA_exons_list:
    if TE in TE_subfamily:
        #print(TE + ' found')
        TE_subfamily_exons.append(TE)
        TE_class_exons.append(map[TE])
    else:
        #print(TE + ' not found')
        TE_not_found_exons.append(TE)
print(TE_subfamily_exons)
# Out:
# ['Alu', 'AluSq4', 'AluYa5', 'AluYc3', 'AluYf1', 'AluYg6', 'AluYh3a3', 'AluYk2', 'AluYk3', 'AluYk4', 'AmnSINE1', 'AmnSINE2', 'Charlie10', 'Charlie11', 'Charlie13a', 'Charlie17', 'Charlie17a', 'Charlie1b', 'Charlie3', 'Charlie4', 'Charlie4z', 'Charlie6', 'Charlie7a', 'Charlie9', 'CR1-3_Croc', 'ERV24_Prim-int', 'ERV3-16A3_I-int', 'ERVL-int', 'FordPrefect', 'HAL1M8', 'Harlequin-int', 'hAT-N1_Mam', 'HERV-Fc1-int', 'HERV16-int', 'HERV17-int', 'HERV3-int', 'HERV35I-int', 'HERV4_I-int', 'HERVE_a-int', 'HERVE-int', 'HERVH-int', 'HERVH48-int', 'HERVI-int', 'HERVIP10B3-int', 'HERVIP10F-int', 'HERVIP10FH-int', 'HERVK-int', 'HERVK11-int', 'HERVK22-int', 'HERVK3-int', 'HERVK9-int', 'HERVL-int', 'HERVL18-int', 'HERVL66-int', 'HERVS71-int', 'HUERS-P2-int', 'HUERS-P3-int', 'Kanga1', 'Kanga11a', 'Kanga1a', 'Kanga1b', 'Kanga1c', 'Kanga1d', 'Kanga2_a', 'L1HS', 'L1M1', 'L1M2', 'L1M2a1', 'L1M2b', 'L1M2c', 'L1M3', 'L1M3a', 'L1M3b', 'L1M3c', 'L1M3e', 'L1M3f', 'L1M4a2', 'L1M4c', 'L1M6', 'L1M7', 'L1M8', 'L1MA
# ...

# %%
normal_tissues_exons = normal_tissues_exons.set_index(normal_tissues_exons.columns[0])
normal_tissues_exons = normal_tissues_exons[(normal_tissues_exons!=0).any(axis=1)]
normal_tissues_exons
# Out:
#             TCGA-BT-A20U-11A-11R-A14Y-07  ...  TCGA-BT-A2LB-11A-11R-A18C-07
# Unnamed: 0                                ...
# (A)n                            0.000000  ...                      0.000000
# (AAAAAC)n                       0.000000  ...                      0.000000
# (AAAAC)n                        0.000000  ...                      0.000000
# (AAAG)n                         0.000000  ...                      0.000000
# (AACA)n                         0.000000  ...                      0.000000
# ...                                  ...  ...                           ...
# X8_LINE                         0.082141  ...                      0.000000
# X9_LINE                         4.448759  ...                      2.775670
# Zaphod                          0.000000  ...                      0.000000
# Zaphod2                         0.190217  ...                      8.821590
# Zaphod3                         0.570533  ...                      2.118705
#
# ...

# %%
normal_exons_list = normal_tissues_exons.index.tolist()

# %%
list_for_index_exon = []
for x in normal_exons_list:
    if x in TE_subfamily_exons:
        list_for_index_exon.append(x)
    else:
        continue

# %%
normal_tissues_exons_final = normal_tissues_exons.loc[list_for_index_exon]

# %%
normal_tissues_exons_final
# Out:
#             TCGA-BT-A20U-11A-11R-A14Y-07  ...  TCGA-BT-A2LB-11A-11R-A18C-07
# Unnamed: 0                                ...
# Alu                             0.000000  ...                      0.951551
# AluSq4                          2.462632  ...                      1.679193
# AluYa5                          0.000000  ...                      0.906804
# AluYc3                          0.000000  ...                      0.000000
# AluYf1                          4.168620  ...                     12.217060
# ...                                  ...  ...                           ...
# X7B_LINE                       18.031973  ...                     19.508821
# X7C_LINE                        0.658674  ...                      0.195727
# X8_LINE                         0.082141  ...                      0.000000
# Zaphod                          0.000000  ...                      0.000000
# Zaphod2                         0.190217  ...                      8.821590
#
# ...

# %%
subfamily_exons_normal_mean = normal_tissues_exons_final.mean(axis=1)
subfamily_exons_normal_mean.head(50)
subfamily_exons_normal_mean.to_csv("subfamily_exons_normal_mean.csv")

# %%
list_exons = list(normal_tissues_exons_final.index.values)
list_class_exons = []
for x in list_exons:
    list_class_exons.append(map[x])

# %%
normal_tissues_exons_final['Class'] = list_class_exons
normal_tissues_exons_final = normal_tissues_exons_final.set_index('Class')

# %%
normal_tissues_exons_final_transposed = normal_tissues_exons_final.T
normal_tissues_exons_final_transposed
normal_tissues_exons_final_transposed.groupby(by=normal_tissues_exons_final_transposed.columns, axis=1).mean().mean()
# Out:
# Class
# DNA           33.775877
# LINE          67.771455
# LTR           53.419268
# Retroposon    86.383855
# SINE           4.870721
# dtype: float64

# %%
normal_tissues_intergenic = intergenic_counts[normal_tissues_with_RNA]

# %%
normal_tissues_intergenic = normal_tissues_intergenic.set_index(normal_tissues_intergenic.columns[0])
normal_tissues_intergenic = normal_tissues_intergenic[(normal_tissues_intergenic!=0).any(axis=1)]
normal_tissues_intergenic
# Out:
#             TCGA-BT-A20U-11A-11R-A14Y-07  ...  TCGA-BT-A2LB-11A-11R-A18C-07
# Unnamed: 0                                ...
# (A)n                             1.00000  ...                      5.989531
# (AAAAAC)n                        0.00000  ...                      0.999707
# (AAAAACC)n                       0.00000  ...                      0.000000
# (AAAAAG)n                        1.00000  ...                      0.000000
# (AAAAAT)n                        0.00000  ...                      1.000000
# ...                                  ...  ...                           ...
# X8_LINE                          0.00000  ...                      2.000000
# X9_LINE                          5.00000  ...                     22.000000
# Zaphod                          53.63466  ...                     68.908700
# Zaphod2                          4.00000  ...                      7.000000
# Zaphod3                         12.00000  ...                     51.000000
#
# ...

# %%
RNA_intergenic_list = intergenic_counts['Unnamed: 0'].tolist()

# %%
len(RNA_intergenic_list)
# Out:
# 10670

# %%
TE_class_intergenic = []
TE_subfamily_intergenic = []
TE_not_found_intergenic = []
for TE in RNA_intergenic_list:
    if TE in TE_subfamily:
        #print(TE + ' found')
        TE_subfamily_intergenic.append(TE)
        TE_class_intergenic.append(map[TE])
    else:
        #print(TE + ' not found')
        TE_not_found_intergenic.append(TE)
print(TE_subfamily_intergenic)
# Out:
# ['Alu', 'AluSq4', 'AluYa5', 'AluYc3', 'AluYf1', 'AluYg6', 'AluYh3a3', 'AluYk2', 'AluYk3', 'AluYk4', 'AmnSINE1', 'AmnSINE2', 'Charlie10', 'Charlie11', 'Charlie13a', 'Charlie17', 'Charlie17a', 'Charlie1b', 'Charlie3', 'Charlie4', 'Charlie4z', 'Charlie6', 'Charlie7a', 'Charlie9', 'CR1-3_Croc', 'ERV24_Prim-int', 'ERV3-16A3_I-int', 'ERVL-int', 'FordPrefect', 'FordPrefect_a', 'HAL1M8', 'Harlequin-int', 'hAT-N1_Mam', 'HERV-Fc1-int', 'HERV-Fc2-int', 'HERV1_I-int', 'HERV1_LTRc', 'HERV1_LTRd', 'HERV15-int', 'HERV16-int', 'HERV17-int', 'HERV3-int', 'HERV30-int', 'HERV35I-int', 'HERV4_I-int', 'HERV9-int', 'HERV9N-int', 'HERV9NC-int', 'HERVE_a-int', 'HERVE-int', 'HERVFH19-int', 'HERVFH21-int', 'HERVH-int', 'HERVH48-int', 'HERVI-int', 'HERVIP10B3-int', 'HERVIP10F-int', 'HERVIP10FH-int', 'HERVK-int', 'HERVK11-int', 'HERVK11D-int', 'HERVK13-int', 'HERVK14C-int', 'HERVK22-int', 'HERVK3-int', 'HERVK9-int', 'HERVL-int', 'HERVL18-int', 'HERVL66-int', 'HERVP71A-int', 'HERVS71-int', 'HUERS-P2-int', 'HUERS
# ...

# %%
normal_tissues_intergenic_final = normal_tissues_intergenic.loc[TE_subfamily_intergenic]
normal_tissues_intergenic_final
# Out:
#             TCGA-BT-A20U-11A-11R-A14Y-07  ...  TCGA-BT-A2LB-11A-11R-A18C-07
# Unnamed: 0                                ...
# Alu                            12.155798  ...                      6.286843
# AluSq4                         29.883425  ...                     50.816381
# AluYa5                         51.184073  ...                     85.065182
# AluYc3                         22.976020  ...                     23.046750
# AluYf1                         79.550609  ...                     50.874589
# ...                                  ...  ...                           ...
# X7B_LINE                       11.000000  ...                      7.000000
# X7C_LINE                        4.000000  ...                      8.000000
# X8_LINE                         0.000000  ...                      2.000000
# Zaphod                         53.634660  ...                     68.908700
# Zaphod2                         4.000000  ...                      7.000000
#
# ...

# %%
subfamily_intergenic_normal_mean = normal_tissues_intergenic_final.mean(axis=1)
subfamily_intergenic_normal_mean.head(50)
subfamily_intergenic_normal_mean.to_csv("subfamily_intergenic_normal_mean.csv")

# %%
list_intergenic = list(normal_tissues_intergenic_final.index.values)
list_class_intergenic = []
for x in list_intergenic:
    list_class_intergenic.append(map[x])

# %%
normal_tissues_intergenic_final['Class'] = list_class_intergenic
normal_tissues_intergenic_final = normal_tissues_intergenic_final.set_index('Class')

# %%
normal_tissues_intergenic_final_transposed = normal_tissues_intergenic_final.T
normal_tissues_intergenic_final_transposed
normal_tissues_intergenic_final_transposed.groupby(by=normal_tissues_intergenic_final_transposed.columns, axis=1).mean().mean()
# Out:
# Class
# DNA            45.472138
# LINE          284.113585
# LTR            96.302888
# Retroposon    469.720678
# SINE           33.854482
# dtype: float64

# %%
significant_TE_introns
# Out:
#     Unnamed: 0    baseMean  log2FoldChange     lfcSE    pvalue      padj
# 0        (AC)n  104.608291       -0.515701  0.183712  0.001231  0.010356
# 1    (ACACAT)n   10.829772        0.593192  0.342293  0.007697  0.042755
# 2    (ACAGAG)n    1.962227       -1.988713  0.466342  0.000002  0.000043
# 3        (AT)n   11.954008       -0.475008  0.207061  0.005264  0.032422
# 4    (ATCACC)n    6.034129       -1.239282  0.337534  0.000019  0.000333
# ..         ...         ...             ...       ...       ...       ...
# 269   Tigger9b   35.537208       -0.305521  0.095954  0.000760  0.007074
# 270     UCON20    1.147858       -0.697132  0.462475  0.008636  0.046736
# 271     UCON34    0.440691       -2.094500  0.523810  0.000010  0.000200
# 272     UCON74   10.237024       -0.494887  0.187574  0.001826  0.014142
# 273   X7A_LINE    8.658324       -0.668664  0.158350  0.000003  0.000058
#
# [274 rows x 6 columns]

# %%
significant_TE_introns = significant_TE_introns[["Unnamed: 0"]]
significant_TE_introns
# Out:
#     Unnamed: 0
# 0        (AC)n
# 1    (ACACAT)n
# 2    (ACAGAG)n
# 3        (AT)n
# 4    (ATCACC)n
# ..         ...
# 269   Tigger9b
# 270     UCON20
# 271     UCON34
# 272     UCON74
# 273   X7A_LINE
#
# [274 rows x 1 columns]

# %%
len(RNA_introns_list)
# Out:
# 11415

# %%
tumor_introns_count
# Out:
#        Unnamed: 0  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# 0            (A)n  ...                     73.439679
# 1      (AAAAAAC)n  ...                      0.000000
# 2      (AAAAAAG)n  ...                      0.000000
# 3      (AAAAAAT)n  ...                      0.000000
# 4       (AAAAAC)n  ...                      0.000000
# ...           ...  ...                           ...
# 11410     X8_LINE  ...                      0.000000
# 11411     X9_LINE  ...                      1.979140
# 11412      Zaphod  ...                     40.708487
# 11413     Zaphod2  ...                      1.691109
# 11414     Zaphod3  ...                    119.770110
#
# [11415 rows x 415 columns]

# %%
tumor_tissues_introns = tumor_introns_count.set_index(tumor_introns_count.columns[0])
tumor_tissues_introns
# Out:
#             TCGA-UY-A9PF-01A-11R-A38B-07  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# Unnamed: 0                                ...
# (A)n                            5.421094  ...                     73.439679
# (AAAAAAC)n                      0.000000  ...                      0.000000
# (AAAAAAG)n                      0.000000  ...                      0.000000
# (AAAAAAT)n                      0.000000  ...                      0.000000
# (AAAAAC)n                       0.000000  ...                      0.000000
# ...                                  ...  ...                           ...
# X8_LINE                         0.000000  ...                      0.000000
# X9_LINE                         0.000000  ...                      1.979140
# Zaphod                         17.395931  ...                     40.708487
# Zaphod2                         2.336998  ...                      1.691109
# Zaphod3                        36.216235  ...                    119.770110
#
# ...

# %%
tumor_tissues_introns = tumor_tissues_introns[(tumor_tissues_introns!=0).any(axis=1)]
tumor_tissues_introns
# Out:
#             TCGA-UY-A9PF-01A-11R-A38B-07  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# Unnamed: 0                                ...
# (A)n                            5.421094  ...                     73.439679
# (AAAAAAC)n                      0.000000  ...                      0.000000
# (AAAAAAT)n                      0.000000  ...                      0.000000
# (AAAAAC)n                       0.000000  ...                      0.000000
# (AAAAACA)n                      0.000000  ...                      0.000000
# ...                                  ...  ...                           ...
# X8_LINE                         0.000000  ...                      0.000000
# X9_LINE                         0.000000  ...                      1.979140
# Zaphod                         17.395931  ...                     40.708487
# Zaphod2                         2.336998  ...                      1.691109
# Zaphod3                        36.216235  ...                    119.770110
#
# ...

# %%
tumor_tissues_introns_final = tumor_tissues_introns.loc[TE_subfamily_introns]
tumor_tissues_introns_final
# Out:
#             TCGA-UY-A9PF-01A-11R-A38B-07  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# Unnamed: 0                                ...
# Alu                             4.098966  ...                     10.577671
# AluSq4                         60.337983  ...                     68.042914
# AluYa5                          8.209876  ...                    112.246841
# AluYc3                         26.863067  ...                     31.304829
# AluYf1                         37.979071  ...                     86.315022
# ...                                  ...  ...                           ...
# X7B_LINE                        3.239670  ...                      2.135424
# X7C_LINE                        7.660810  ...                      4.256061
# X8_LINE                         0.000000  ...                      0.000000
# Zaphod                         17.395931  ...                     40.708487
# Zaphod2                         2.336998  ...                      1.691109
#
# ...

# %%
subfamily_introns_tumor_mean = tumor_tissues_introns_final.mean(axis=1)
subfamily_introns_tumor_mean.head(50)
subfamily_introns_tumor_mean.to_csv("subfamily_introns_tumor_mean.csv")

# %%
list_introns_tumor = list(tumor_tissues_introns_final.index.values)
list_class_introns_tumor = []
for x in list_introns_tumor:
    list_class_introns_tumor.append(map[x])

# %%
tumor_tissues_introns_final['Class'] = list_class_introns_tumor
tumor_tissues_introns_final = tumor_tissues_introns_final.set_index('Class')

# %%
tumor_tissues_introns_final_transposed = tumor_tissues_introns_final.T
tumor_tissues_introns_final_transposed
tumor_tissues_introns_final_transposed.groupby(by=tumor_tissues_introns_final_transposed.columns, axis=1).mean().mean()
# Out:
# Class
# DNA            40.963414
# LINE          310.961605
# LTR            87.885546
# Retroposon    762.104375
# SINE           35.907530
# dtype: float64

# %%
tumor_intergenic_counts
# Out:
#        Unnamed: 0  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# 0            (A)n  ...                      59.38362
# 1          (AAA)n  ...                       0.00000
# 2      (AAAAAAC)n  ...                       0.00000
# 3      (AAAAAAG)n  ...                       0.00000
# 4      (AAAAAAT)n  ...                       0.00000
# ...           ...  ...                           ...
# 10665     X8_LINE  ...                       1.00000
# 10666     X9_LINE  ...                      20.00000
# 10667      Zaphod  ...                     243.27083
# 10668     Zaphod2  ...                      21.00000
# 10669     Zaphod3  ...                      87.00000
#
# [10670 rows x 415 columns]

# %%
tumor_tissues_intergenic = tumor_intergenic_counts.set_index(tumor_intergenic_counts.columns[0])
tumor_tissues_intergenic
# Out:
#             TCGA-UY-A9PF-01A-11R-A38B-07  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# Unnamed: 0                                ...
# (A)n                            5.000000  ...                      59.38362
# (AAA)n                          0.000000  ...                       0.00000
# (AAAAAAC)n                      0.000000  ...                       0.00000
# (AAAAAAG)n                      0.000000  ...                       0.00000
# (AAAAAAT)n                      0.000000  ...                       0.00000
# ...                                  ...  ...                           ...
# X8_LINE                         1.000000  ...                       1.00000
# X9_LINE                        10.000000  ...                      20.00000
# Zaphod                         45.000000  ...                     243.27083
# Zaphod2                         7.918243  ...                      21.00000
# Zaphod3                        28.000000  ...                      87.00000
#
# ...

# %%
tumor_tissues_intergenic = tumor_tissues_intergenic[(tumor_tissues_intergenic!=0).any(axis=1)]
tumor_tissues_intergenic
# Out:
#             TCGA-UY-A9PF-01A-11R-A38B-07  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# Unnamed: 0                                ...
# (A)n                            5.000000  ...                      59.38362
# (AAAAAAC)n                      0.000000  ...                       0.00000
# (AAAAAAG)n                      0.000000  ...                       0.00000
# (AAAAAC)n                       0.996945  ...                       0.00000
# (AAAAACA)n                      0.000000  ...                       0.00000
# ...                                  ...  ...                           ...
# X8_LINE                         1.000000  ...                       1.00000
# X9_LINE                        10.000000  ...                      20.00000
# Zaphod                         45.000000  ...                     243.27083
# Zaphod2                         7.918243  ...                      21.00000
# Zaphod3                        28.000000  ...                      87.00000
#
# ...

# %%
tumor_tissues_intergenic_final = tumor_tissues_intergenic.loc[TE_subfamily_intergenic]
tumor_tissues_intergenic_final
# Out:
#             TCGA-UY-A9PF-01A-11R-A38B-07  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# Unnamed: 0                                ...
# Alu                             8.713811  ...                     20.710323
# AluSq4                         42.928400  ...                     78.019730
# AluYa5                         27.335246  ...                     35.055278
# AluYc3                         15.596137  ...                     29.666855
# AluYf1                         34.608723  ...                    231.239172
# ...                                  ...  ...                           ...
# X7B_LINE                       10.000000  ...                     20.000000
# X7C_LINE                        4.000000  ...                     10.000000
# X8_LINE                         1.000000  ...                      1.000000
# Zaphod                         45.000000  ...                    243.270830
# Zaphod2                         7.918243  ...                     21.000000
#
# ...

# %%
subfamily_intergenic_tumor_mean = tumor_tissues_intergenic_final.mean(axis=1)
subfamily_intergenic_tumor_mean.head(50)
subfamily_intergenic_tumor_mean.to_csv("subfamily_intergenic_tumor_mean.csv")

# %%
list_intergenic_tumor = list(tumor_tissues_intergenic_final.index.values)
list_class_intergenic_tumor = []
for x in list_intergenic_tumor:
    list_class_intergenic_tumor.append(map[x])

# %%
tumor_tissues_intergenic_final['Class'] = list_class_intergenic_tumor
tumor_tissues_intergenic_final = tumor_tissues_intergenic_final.set_index('Class')

# %%
tumor_tissues_intergenic_final_transposed = tumor_tissues_intergenic_final.T
tumor_tissues_intergenic_final_transposed
tumor_tissues_intergenic_final_transposed.groupby(by=tumor_tissues_intergenic_final_transposed.columns, axis=1).mean().mean()
# Out:
# Class
# DNA             76.245161
# LINE           550.626446
# LTR            216.551333
# Retroposon    1067.393058
# SINE            54.377614
# dtype: float64

# %%
tumor_exon_count
# Out:
#       Unnamed: 0  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# 0           (A)n  ...                       0.00000
# 1      (AAAAAC)n  ...                       0.00000
# 2     (AAAAACA)n  ...                       0.00000
# 3      (AAAAAG)n  ...                       0.00000
# 4      (AAAAAT)n  ...                       0.00000
# ...          ...  ...                           ...
# 4574     X8_LINE  ...                       2.59926
# 4575     X9_LINE  ...                       3.54121
# 4576      Zaphod  ...                       0.00000
# 4577     Zaphod2  ...                       0.00000
# 4578     Zaphod3  ...                       2.84821
#
# [4579 rows x 415 columns]

# %%
tumor_tissues_exon = tumor_exon_count.set_index(tumor_exon_count.columns[0])
tumor_tissues_exon
# Out:
#             TCGA-UY-A9PF-01A-11R-A38B-07  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# Unnamed: 0                                ...
# (A)n                            0.000000  ...                       0.00000
# (AAAAAC)n                       0.000000  ...                       0.00000
# (AAAAACA)n                      0.000000  ...                       0.00000
# (AAAAAG)n                       0.000000  ...                       0.00000
# (AAAAAT)n                       0.000000  ...                       0.00000
# ...                                  ...  ...                           ...
# X8_LINE                         0.033193  ...                       2.59926
# X9_LINE                         4.391797  ...                       3.54121
# Zaphod                          1.414540  ...                       0.00000
# Zaphod2                         3.677880  ...                       0.00000
# Zaphod3                         3.196492  ...                       2.84821
#
# ...

# %%
tumor_tissues_exon = tumor_tissues_exon[(tumor_tissues_exon!=0).any(axis=1)]
tumor_tissues_exon
# Out:
#             TCGA-UY-A9PF-01A-11R-A38B-07  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# Unnamed: 0                                ...
# (A)n                            0.000000  ...                       0.00000
# (AAAAAC)n                       0.000000  ...                       0.00000
# (AAAAAT)n                       0.000000  ...                       0.00000
# (AAAAC)n                        0.000000  ...                       0.00000
# (AAAACA)n                       0.000000  ...                       0.00000
# ...                                  ...  ...                           ...
# X8_LINE                         0.033193  ...                       2.59926
# X9_LINE                         4.391797  ...                       3.54121
# Zaphod                          1.414540  ...                       0.00000
# Zaphod2                         3.677880  ...                       0.00000
# Zaphod3                         3.196492  ...                       2.84821
#
# ...

# %%
tumor_tissues_exon_final = tumor_tissues_exon.loc[['Alu', 'AluSq4', 'AluYa5', 'AluYc3', 'AluYf1', 'AluYg6', 'AluYh3a3', 'AluYk2', 'AluYk3', 'AluYk4', 'AmnSINE1', 'AmnSINE2', 'Charlie10', 'Charlie11', 'Charlie13a', 'Charlie17', 'Charlie17a', 'Charlie1b', 'Charlie3', 'Charlie4', 'Charlie4z', 'Charlie6', 'Charlie7a', 'Charlie9', 'CR1-3_Croc', 'ERV24_Prim-int', 'ERV3-16A3_I-int', 'ERVL-int', 'FordPrefect', 'HAL1M8', 'Harlequin-int', 'hAT-N1_Mam', 'HERV-Fc1-int', 'HERV16-int', 'HERV17-int', 'HERV3-int', 'HERV35I-int', 'HERV4_I-int', 'HERVE_a-int', 'HERVE-int', 'HERVH-int', 'HERVH48-int', 'HERVI-int', 'HERVIP10B3-int', 'HERVIP10F-int', 'HERVIP10FH-int', 'HERVK-int', 'HERVK11-int', 'HERVK22-int', 'HERVK3-int', 'HERVK9-int', 'HERVL-int', 'HERVL18-int', 'HERVL66-int', 'HERVS71-int', 'HUERS-P2-int', 'HUERS-P3-int', 'Kanga1', 'Kanga11a', 'Kanga1a', 'Kanga1b', 'Kanga1c', 'Kanga1d', 'Kanga2_a', 'L1HS', 'L1M1', 'L1M2', 'L1M2a1', 'L1M2b', 'L1M2c', 'L1M3', 'L1M3a', 'L1M3b', 'L1M3c', 'L1M3e', 'L1M3f', 'L1M4a2', 'L1M4c', 'L1M6', 'L1M7', 'L1M8', 'L1MA1', 'L1MA10', 'L1MA3', 'L1MA4A', 'L1MB1', 'L1MC', 'L1MD3', 'L1ME3D', 'L1ME3F', 'L1MEa', 'L1MEg1', 'L1MEg2', 'L1P1', 'L1P2', 'L1P3', 'L1P4', 'L1P4a', 'L1P4d', 'L1PA11', 'L1PA12', 'L1PA13', 'L1PA14', 'L1PA15', 'L1PA15-16', 'L1PA2', 'L1PA3', 'L1PA5', 'L1PA6', 'L1PA7', 'L1PA8', 'L1PA8A', 'L1PB1', 'L1PB2', 'L1PB3', 'L1PBa', 'L1PBa1', 'L1PBb', 'L1PREC2', 'L2-1_AMi', 'L4_B_Mam', 'Looper', 'LOR1-int', 'LOR1a', 'LTR102_Mam', 'LTR103b_Mam', 'LTR105_Mam', 'LTR106_Mam', 'LTR10A', 'LTR10C', 'LTR10E', 'LTR10F', 'LTR12B', 'LTR12C', 'LTR12D', 'LTR12F', 'LTR14', 'LTR14A', 'LTR14C', 'LTR16A2', 'LTR16B1', 'LTR16B2', 'LTR16D', 'LTR16D2', 'LTR16E2', 'LTR18A', 'LTR18B', 'LTR19A', 'LTR19B', 'LTR1A2', 'LTR1B', 'LTR1B0', 'LTR1C', 'LTR1D', 'LTR1F', 'LTR1F1', 'LTR2', 'LTR21A', 'LTR21B', 'LTR22A', 'LTR22E', 'LTR23', 'LTR24C', 'LTR26B', 'LTR26C', 'LTR26E', 'LTR2752', 'LTR27B', 'LTR27C', 'LTR27D', 'LTR27E', 'LTR28C', 'LTR29', 'LTR2B', 'LTR2C', 'LTR31', 'LTR33A_', 'LTR33C', 'LTR35B', 'LTR37-int', 'LTR37A', 'LTR38', 'LTR38A1', 'LTR39', 'LTR39-int', 'LTR3A', 'LTR3B', 'LTR4', 'LTR40a', 'LTR40A1', 'LTR40c', 'LTR41', 'LTR43', 'LTR43-int', 'LTR44', 'LTR45', 'LTR45B', 'LTR45C', 'LTR46', 'LTR46-int', 'LTR47B2', 'LTR48', 'LTR48B', 'LTR49-int', 'LTR5_Hs', 'LTR51', 'LTR52', 'LTR53B', 'LTR55', 'LTR56', 'LTR57', 'LTR57-int', 'LTR61', 'LTR62', 'LTR64', 'LTR65', 'LTR66', 'LTR6A', 'LTR6B', 'LTR7', 'LTR70', 'LTR71B', 'LTR72', 'LTR73', 'LTR75', 'LTR75_1', 'LTR76', 'LTR7B', 'LTR7C', 'LTR7Y', 'LTR80B', 'LTR81B', 'LTR81C', 'LTR82A', 'LTR84a', 'LTR84b', 'LTR85a', 'LTR85b', 'LTR85c', 'LTR86C', 'LTR88c', 'LTR9', 'LTR90B', 'LTR9A1', 'LTR9D', 'Mam_R4', 'MamGyp-int', 'MamGypLTR1a', 'MamGypsy2-I', 'MamGypsy2-LTR', 'MamRep1527', 'MamRep1894', 'MamRep4096', 'MamTip3', 'MER101', 'MER101B', 'MER102b', 'MER102c', 'MER105', 'MER110', 'MER110-int', 'MER113B', 'MER11A', 'MER11B', 'MER11C', 'MER11D', 'MER121', 'MER1B', 'MER20B', 'MER34', 'MER34-int', 'MER34A', 'MER34A1', 'MER34B', 'MER34B-int', 'MER34C2', 'MER34D', 'MER39', 'MER4-int', 'MER41A', 'MER41C', 'MER41G', 'MER44D', 'MER45B', 'MER45C', 'MER47C', 'MER48', 'MER49', 'MER4A', 'MER4A1', 'MER4A1_', 'MER4B-int', 'MER4C', 'MER4D', 'MER4D0', 'MER50', 'MER50-int', 'MER50B', 'MER50C', 'MER51-int', 'MER51A', 'MER51B', 'MER51C', 'MER51D', 'MER51E', 'MER52-int', 'MER52A', 'MER52C', 'MER52D', 'MER54B', 'MER57-int', 'MER57A-int', 'MER57A1', 'MER57B1', 'MER57B2', 'MER57C2', 'MER57D', 'MER57E1', 'MER57F', 'MER61-int', 'MER61A', 'MER61B', 'MER61C', 'MER61D', 'MER61E', 'MER61F', 'MER63B', 'MER65C', 'MER65D', 'MER66A', 'MER66B', 'MER66C', 'MER66D', 'MER67A', 'MER67D', 'MER68', 'MER68-int', 'MER68B', 'MER6A', 'MER70-int', 'MER70A', 'MER70B', 'MER74C', 'MER75', 'MER76', 'MER77', 'MER83', 'MER84', 'MER87', 'MER87B', 'MER89-int', 'MER90', 'MER91C', 'MER94B', 'MER96', 'MER96B', 'MER97b', 'MER9a1', 'MER9a2', 'MER9a3', 'MLT1-int', 'MLT1A-int', 'MLT1A0-int', 'MLT1C-int', 'MLT1E', 'MLT1E1', 'MLT1E1A', 'MLT1E2-int', 'MLT1E3', 'MLT1G', 'MLT1G-int', 'MLT1G3', 'MLT1H-int', 'MLT1H2', 'MLT1I-int', 'MLT1J1-int', 'MLT1J2-int', 'MLT1K-int', 'MLT2B1', 'MLT2B5', 'MLT2C2', 'MST-int', 'MSTA-int', 'MSTB1', 'MSTD', 'MSTD-int', 'ORSL-2a', 'ORSL-2b', 'PABL_A', 'PABL_A-int', 'PABL_B', 'PABL_B-int', 'PRIMA41-int', 'PrimLTR79', 'SVA_A', 'SVA_B', 'SVA_C', 'SVA_D', 'SVA_E', 'SVA_F', 'THE1D-int', 'Tigger12c', 'Tigger16b', 'Tigger17c', 'Tigger3c', 'Tigger4', 'Tigger5', 'Tigger8', 'Tigger9a', 'X7B_LINE', 'X7C_LINE', 'X8_LINE', 'Zaphod', 'Zaphod2']]
tumor_tissues_exon_final
# Out:
#             TCGA-UY-A9PF-01A-11R-A38B-07  ...  TCGA-GC-A3YS-01A-11R-A23N-07
# Unnamed: 0                                ...
# Alu                             0.000000  ...                      0.000000
# AluSq4                          5.018291  ...                      0.576371
# AluYa5                          0.000000  ...                      0.000000
# AluYc3                          0.482792  ...                      0.000000
# AluYf1                          1.728263  ...                      0.063766
# ...                                  ...  ...                           ...
# X7B_LINE                        0.440124  ...                      4.395930
# X7C_LINE                        2.884640  ...                      4.482689
# X8_LINE                         0.033193  ...                      2.599260
# Zaphod                          1.414540  ...                      0.000000
# Zaphod2                         3.677880  ...                      0.000000
#
# ...

# %%
subfamily_exon_tumor_mean = tumor_tissues_exon_final.mean(axis=1)
subfamily_exon_tumor_mean.head(50)
subfamily_exon_tumor_mean.to_csv("subfamily_exon_tumor_mean.csv")

# %%
list_exon_tumor = list(tumor_tissues_exon_final.index.values)
list_class_exon_tumor = []
for x in list_exon_tumor:
    list_class_exon_tumor.append(map[x])

# %%
tumor_tissues_exon_final['Class'] = list_class_exon_tumor
tumor_tissues_exon_final = tumor_tissues_exon_final.set_index('Class')

# %%
tumor_tissues_exon_final_transposed = tumor_tissues_exon_final.T
tumor_tissues_exon_final_transposed
tumor_tissues_exon_final_transposed.groupby(by=tumor_tissues_exon_final_transposed.columns, axis=1).mean().mean()
# Out:
# Class
# DNA            41.120363
# LINE           76.865944
# LTR            84.073026
# Retroposon    146.791148
# SINE            6.700918
# dtype: float64
